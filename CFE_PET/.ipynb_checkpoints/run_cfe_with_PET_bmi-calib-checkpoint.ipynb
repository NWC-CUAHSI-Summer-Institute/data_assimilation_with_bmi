# %%
# !pip install eto
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import bmi_cfe
import bmi_PET
from fao_pet import ETRCalculator
import matplotlib.pyplot as plt
from bmi_cfe import BMI_CFE
# Out:
# Requirement already satisfied: eto in /opt/conda/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from eto) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas->eto) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->eto) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas->eto) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from pandas->eto) (1.24.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->eto) (1.16.0)

# %%
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from bmi_cfe import BMI_CFE

# %%
input_dir = './Carmel_inputs_January_2017/config_json_updated'
forcing_dir = './Carmel_inputs_January_2017/forcings'
# output_dir = './output_dir/cfe_output_2017'
output_dir = './Carmel_inputs_January_2017/output_decjanfeb'

# %%
# input_dir = './Carmel_inputs_January_2017/pet_config'
# forcing_dir = './Carmel_inputs_January_2017/forcings'
# # output_dir = './output_dir/cfe_output_2017'
# output_dir = './Carmel_inputs_January_2017/output_decjanfeb'

# %%
# pip install dataretrieval

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# import os
# import json

# def modify_json_key(json_file_path, new_key, filepath, output_directory):
#     with open(json_file_path, 'r') as f:
#         data = json.load(f)

#     # Get the filename without the extension
#     filename_without_extension = os.path.splitext(os.path.basename(json_file_path))[0]
    
#     filename_suffix = filename_without_extension.split("PET_Config_")[-1]
#     # Append the new extension
#     csv_filename = filename_suffix + ".csv"
#     # Set the new key's value to be the filepath + name of the csv file
#     # data[new_key] = [1.0, 0.0]
#     data[new_key] = './Carmel_inputs_January_2017/forcings/'+csv_filename
    
#     #Remove the unit_test key from the json file
#     # if 'unit_test' in data:
#     #     del data['unit_test']

#     # Make sure the output directory exists
#     os.makedirs(output_directory, exist_ok=True)

#     # Construct the output file path
#     output_file_path = os.path.join(output_directory, os.path.basename(json_file_path))

#     # Write the updated dictionary back to the JSON file in the output directory
#     with open(output_file_path, 'w') as f:
#         json.dump(data, f, indent=4)

# def modify_all_json_keys(input_directory, output_directory, new_key):
#     for filename in os.listdir(input_directory):
#         if filename.endswith(".json"):
#             json_file_path = os.path.join(input_directory, filename)
#             modify_json_key(json_file_path, new_key, output_directory, output_directory)

# # use the function
# input_dir = input_dir
# output_dir = './Carmel_inputs_January_2017/pet_config/'
# modify_all_json_keys(input_dir, output_dir, 'csv_file_path')

# %% [markdown]
# # 1. Run Normal CFE Simulations

# %%
# istart_plot = 0
# iend_plot = 550
# x = list(range(istart_plot, iend_plot))
# for output in outputs:
#     plt.plot(x, output_lists[output][istart_plot:iend_plot], label=output)
#     plt.title(output)
#     plt.legend()
#     plt.show()
#     plt.close()

# %%
import os
import json
import pandas as pd

# Check if output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate over all files in input_dir
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):  # check if the file is a JSON file
        file_path = os.path.join(input_dir, filename)
        filename_without_extension = os.path.splitext(os.path.basename(file_path))[0]
        # Initialize CFE instance
        cfe_instance = BMI_CFE(file_path)
        cfe_instance.initialize()
        
        pet_instance = bmi_PET.BMI_pet_model()
        pet_instance.initialize(cfg_file='./Carmel_inputs_January_2017/pet_config/PET_Config_'+filename_without_extension+'.json', current_time_step=1)
        # print(cfg_file)
        pet_instance.update()
        pet_instance.finalize()
        pet = pet_instance.get_value('etr').values

        # Construct forcing file name and read forcing file
        forcing_file_name = filename.replace('.json', '.csv')
        forcing_file_path = os.path.join(forcing_dir, forcing_file_name)
        # print(forcing_file_path)

        with open(forcing_file_path, 'r') as f:
            df_forcing = pd.read_csv(f)

        # Initialize output dictionary
        outputs = cfe_instance.get_output_var_names()
        output_lists = {output:[] for output in outputs}

        # Update CFE instance with each precipitation and PET values
        
        for t, precip in enumerate(df_forcing['APCP_surface']):
            precip = (precip)/1000
            pet[t] = pet[t]/3600
            cfe_instance.set_value('atmosphere_water__time_integral_of_precipitation_mass_flux', precip)    
    
            cfe_instance.set_value('water_potential_evaporation_flux', pet[t]*0)
   
            cfe_instance.update()

            for output in outputs:
                output_lists[output].append(cfe_instance.get_value(output))

        cfe_instance.finalize(print_mass_balance=True)

        # Convert output dictionary to DataFrame
        df_output = pd.DataFrame(output_lists)

        # Write output to a CSV file in the output directory
        output_csv_file_path = os.path.join(output_dir, f'{os.path.splitext(filename)[0]}_output.csv')
        df_output.to_csv(output_csv_file_path, index=False)

        # Write output to a JSON file in the output directory
        # output_json_file_path = os.path.join(output_dir, f'{os.path.splitext(filename)[0]}_output.json')
        # with open(output_json_file_path, 'w') as json_file:
        #     json.dump(output_lists, json_file)
# Out:
# GLOBAL MASS BALANCE
#   initial volume:   2.1004
#     volume input:   0.4777
#    volume output:   1.0372
#     final volume:   1.5410
#         residual: 9.3259e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1350
#       infiltration:   0.3427
#  vol. et from rain:   0.0000
# partition residual: -1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1350
#    vol. out giuh:   0.1350
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6166
#     vol. into soil:   0.3427
#   vol.soil2latflow:   0.6825
#    vol. soil to gw:   0.0035
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2733
#   vol. soil resid.: 2.0539e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.6825
#   vol. from nash:   0.6729
#  final vol. nash:   0.0096
# nash casc resid.: -1.4485e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0035
#      vol from gw:   0.2197
# final gw.storage:   1.2677
#     gw. residual: 5.5511e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0575
#     volume input:   0.4013
#    volume output:   1.0983
#     final volume:   1.3605
#         residual: -1.7764e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0943
#       infiltration:   0.3069
#  vol. et from rain:   0.0000
# partition residual: 3.8858e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0943
#    vol. out giuh:   0.0943
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5736
#     vol. into soil:   0.3069
#   vol.soil2latflow:   0.7842
#    vol. soil to gw:   0.0040
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0924
#   vol. soil resid.: -2.4980e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7842
#   vol. from nash:   0.7745
#  final vol. nash:   0.0096
# nash casc resid.: -1.3479e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0040
#      vol from gw:   0.2198
# final gw.storage:   1.2681
#     gw. residual: -4.6629e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0883
#     volume input:   0.7341
#    volume output:   1.1176
#     final volume:   1.7048
#         residual: -1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0635
#       infiltration:   0.6706
#  vol. et from rain:   0.0000
# partition residual: 1.5543e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0635
#    vol. out giuh:   0.0635
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6044
#     vol. into soil:   0.6706
#   vol.soil2latflow:   0.8314
#    vol. soil to gw:   0.0404
#  vol. et from soil:   0.0000
#    final vol. soil:   0.4033
#   vol. soil resid.: -3.1641e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8314
#   vol. from nash:   0.8190
#  final vol. nash:   0.0123
# nash casc resid.: 1.4884e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0404
#      vol from gw:   0.2228
# final gw.storage:   1.3015
#     gw. residual: -1.7764e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4641
#    volume output:   1.1106
#     final volume:   1.4128
#         residual: -1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0622
#       infiltration:   0.4019
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0622
#    vol. out giuh:   0.0622
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.4019
#   vol.soil2latflow:   0.8279
#    vol. soil to gw:   0.0110
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1385
#   vol. soil resid.: 6.6613e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8279
#   vol. from nash:   0.8166
#  final vol. nash:   0.0113
# nash casc resid.: -7.3379e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0110
#      vol from gw:   0.2205
# final gw.storage:   1.2744
#     gw. residual: 1.7764e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.7321
#    volume output:   1.3529
#     final volume:   1.4386
#         residual: -1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1343
#       infiltration:   0.5978
#  vol. et from rain:   0.0000
# partition residual: 6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1343
#    vol. out giuh:   0.1343
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.5978
#   vol.soil2latflow:   0.9979
#    vol. soil to gw:   0.0133
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1620
#   vol. soil resid.: -2.7478e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.9979
#   vol. from nash:   0.9833
#  final vol. nash:   0.0146
# nash casc resid.: 4.1807e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0133
#      vol from gw:   0.2206
# final gw.storage:   1.2766
#     gw. residual: 3.3307e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4846
#    volume output:   1.2151
#     final volume:   1.3288
#         residual: 3.3307e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1304
#       infiltration:   0.3542
#  vol. et from rain:   0.0000
# partition residual: -7.7716e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1304
#    vol. out giuh:   0.1304
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3542
#   vol.soil2latflow:   0.8650
#    vol. soil to gw:   0.0039
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0608
#   vol. soil resid.: 9.5757e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8650
#   vol. from nash:   0.8541
#  final vol. nash:   0.0108
# nash casc resid.: -2.8449e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0039
#      vol from gw:   0.2198
# final gw.storage:   1.2680
#     gw. residual: -4.4409e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.8603
#    volume output:   1.5352
#     final volume:   1.3844
#         residual: -4.8850e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2942
#       infiltration:   0.5661
#  vol. et from rain:   0.0000
# partition residual: 1.2212e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2942
#    vol. out giuh:   0.2942
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.5661
#   vol.soil2latflow:   1.0211
#    vol. soil to gw:   0.0057
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1147
#   vol. soil resid.: -2.0955e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0211
#   vol. from nash:   1.0076
#  final vol. nash:   0.0135
# nash casc resid.: 2.1389e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0057
#      vol from gw:   0.2199
# final gw.storage:   1.2697
#     gw. residual: -6.4393e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0601
#     volume input:   0.8603
#    volume output:   1.5096
#     final volume:   1.4108
#         residual: -1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2266
#       infiltration:   0.6336
#  vol. et from rain:   0.0000
# partition residual: 1.2212e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2266
#    vol. out giuh:   0.2266
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5762
#     vol. into soil:   0.6336
#   vol.soil2latflow:   1.0627
#    vol. soil to gw:   0.0094
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1378
#   vol. soil resid.: 1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0627
#   vol. from nash:   1.0477
#  final vol. nash:   0.0150
# nash casc resid.: 1.5890e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0094
#      vol from gw:   0.2203
# final gw.storage:   1.2730
#     gw. residual: -8.8818e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0598
#     volume input:   0.7517
#    volume output:   1.4457
#     final volume:   1.3658
#         residual: -5.3291e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1315
#       infiltration:   0.6202
#  vol. et from rain:   0.0000
# partition residual: 1.6653e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1315
#    vol. out giuh:   0.1315
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5759
#     vol. into soil:   0.6202
#   vol.soil2latflow:   1.0934
#    vol. soil to gw:   0.0142
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0885
#   vol. soil resid.: 8.8818e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0934
#   vol. from nash:   1.0773
#  final vol. nash:   0.0161
# nash casc resid.: 1.0374e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0142
#      vol from gw:   0.2208
# final gw.storage:   1.2774
#     gw. residual: -1.0214e-14
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4807
#    volume output:   1.1216
#     final volume:   1.4184
#         residual: -1.3323e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0888
#       infiltration:   0.3919
#  vol. et from rain:   0.0000
# partition residual: -6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0888
#    vol. out giuh:   0.0888
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3919
#   vol.soil2latflow:   0.8127
#    vol. soil to gw:   0.0072
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1474
#   vol. soil resid.: 3.8858e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8127
#   vol. from nash:   0.8019
#  final vol. nash:   0.0108
# nash casc resid.: 1.1172e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0072
#      vol from gw:   0.2201
# final gw.storage:   1.2710
#     gw. residual: -4.4409e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0562
#     volume input:   0.4747
#    volume output:   1.1036
#     final volume:   1.4274
#         residual: 6.4393e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0402
#       infiltration:   0.4345
#  vol. et from rain:   0.0000
# partition residual: -3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0402
#    vol. out giuh:   0.0402
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5723
#     vol. into soil:   0.4345
#   vol.soil2latflow:   0.8420
#    vol. soil to gw:   0.0192
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1456
#   vol. soil resid.: 1.2212e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8420
#   vol. from nash:   0.8289
#  final vol. nash:   0.0131
# nash casc resid.: -3.1936e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0192
#      vol from gw:   0.2213
# final gw.storage:   1.2818
#     gw. residual: 6.6613e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0861
#     volume input:   0.3469
#    volume output:   0.8596
#     final volume:   1.5734
#         residual: 3.3307e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0624
#       infiltration:   0.2845
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0624
#    vol. out giuh:   0.0624
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6022
#     vol. into soil:   0.2845
#   vol.soil2latflow:   0.5773
#    vol. soil to gw:   0.0050
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3043
#   vol. soil resid.: 1.2768e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.5773
#   vol. from nash:   0.5681
#  final vol. nash:   0.0091
# nash casc resid.: 9.2981e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0050
#      vol from gw:   0.2198
# final gw.storage:   1.2691
#     gw. residual: 0.0000e+00
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0591
#     volume input:   0.3898
#    volume output:   0.9999
#     final volume:   1.4490
#         residual: 4.4409e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0095
#       infiltration:   0.3803
#  vol. et from rain:   0.0000
# partition residual: 1.7764e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0095
#    vol. out giuh:   0.0095
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5752
#     vol. into soil:   0.3803
#   vol.soil2latflow:   0.7642
#    vol. soil to gw:   0.0649
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1265
#   vol. soil resid.: -1.2768e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7642
#   vol. from nash:   0.7516
#  final vol. nash:   0.0125
# nash casc resid.: 1.6584e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0649
#      vol from gw:   0.2263
# final gw.storage:   1.3225
#     gw. residual: 8.8818e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4623
#    volume output:   1.1945
#     final volume:   1.3272
#         residual: 1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2323
#       infiltration:   0.2300
#  vol. et from rain:   0.0000
# partition residual: -1.0270e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2323
#    vol. out giuh:   0.2323
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.2300
#   vol.soil2latflow:   0.7428
#    vol. soil to gw:   0.0010
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0618
#   vol. soil resid.: -2.8588e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7428
#   vol. from nash:   0.7359
#  final vol. nash:   0.0068
# nash casc resid.: 3.3099e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0010
#      vol from gw:   0.2194
# final gw.storage:   1.2654
#     gw. residual: 2.6645e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.1001
#     volume input:   1.2750
#    volume output:   1.7790
#     final volume:   1.5961
#         residual: 6.6613e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.6799
#       infiltration:   0.5952
#  vol. et from rain:   0.0000
# partition residual: 1.4433e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.6799
#    vol. out giuh:   0.6799
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6162
#     vol. into soil:   0.5952
#   vol.soil2latflow:   0.8795
#    vol. soil to gw:   0.0038
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3281
#   vol. soil resid.: 8.8818e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8795
#   vol. from nash:   0.8691
#  final vol. nash:   0.0104
# nash casc resid.: -1.6150e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0038
#      vol from gw:   0.2197
# final gw.storage:   1.2680
#     gw. residual: 1.1102e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0992
#     volume input:   0.5844
#    volume output:   1.1261
#     final volume:   1.5574
#         residual: -2.2204e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1463
#       infiltration:   0.4381
#  vol. et from rain:   0.0000
# partition residual: 1.2212e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1463
#    vol. out giuh:   0.1463
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6153
#     vol. into soil:   0.4381
#   vol.soil2latflow:   0.7598
#    vol. soil to gw:   0.0078
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2858
#   vol. soil resid.: -1.3878e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7598
#   vol. from nash:   0.7486
#  final vol. nash:   0.0111
# nash casc resid.: 1.1345e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0078
#      vol from gw:   0.2201
# final gw.storage:   1.2716
#     gw. residual: -5.5511e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3616
#    volume output:   1.0190
#     final volume:   1.4020
#         residual: 0.0000e+00
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0212
#       infiltration:   0.3405
#  vol. et from rain:   0.0000
# partition residual: -1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0212
#    vol. out giuh:   0.0212
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3405
#   vol.soil2latflow:   0.7761
#    vol. soil to gw:   0.0218
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1180
#   vol. soil resid.: 2.7756e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7761
#   vol. from nash:   0.7642
#  final vol. nash:   0.0119
# nash casc resid.: -3.9205e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0218
#      vol from gw:   0.2217
# final gw.storage:   1.2840
#     gw. residual: 1.9984e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0595
#     volume input:   0.6918
#    volume output:   1.4015
#     final volume:   1.3498
#         residual: 8.8818e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1767
#       infiltration:   0.5151
#  vol. et from rain:   0.0000
# partition residual: -6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1767
#    vol. out giuh:   0.1767
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5756
#     vol. into soil:   0.5151
#   vol.soil2latflow:   1.0047
#    vol. soil to gw:   0.0070
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0790
#   vol. soil resid.: 1.9568e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0047
#   vol. from nash:   0.9911
#  final vol. nash:   0.0137
# nash casc resid.: -1.9811e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0070
#      vol from gw:   0.2201
# final gw.storage:   1.2708
#     gw. residual: 1.5543e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0572
#     volume input:   0.4131
#    volume output:   1.0758
#     final volume:   1.3945
#         residual: -5.9952e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0461
#       infiltration:   0.3670
#  vol. et from rain:   0.0000
# partition residual: -2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0461
#    vol. out giuh:   0.0461
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5733
#     vol. into soil:   0.3670
#   vol.soil2latflow:   0.8092
#    vol. soil to gw:   0.0116
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1195
#   vol. soil resid.: 4.3021e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8092
#   vol. from nash:   0.7971
#  final vol. nash:   0.0120
# nash casc resid.: -2.4564e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0116
#      vol from gw:   0.2206
# final gw.storage:   1.2750
#     gw. residual: -2.6645e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0768
#     volume input:   0.3551
#    volume output:   0.9794
#     final volume:   1.4526
#         residual: -4.4409e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0343
#       infiltration:   0.3208
#  vol. et from rain:   0.0000
# partition residual: 3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0343
#    vol. out giuh:   0.0343
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5929
#     vol. into soil:   0.3208
#   vol.soil2latflow:   0.7245
#    vol. soil to gw:   0.0115
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1778
#   vol. soil resid.: -1.6376e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7245
#   vol. from nash:   0.7129
#  final vol. nash:   0.0116
# nash casc resid.: 2.4182e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0115
#      vol from gw:   0.2206
# final gw.storage:   1.2748
#     gw. residual: -1.5543e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.8603
#    volume output:   1.5156
#     final volume:   1.4040
#         residual: -5.7732e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2413
#       infiltration:   0.6189
#  vol. et from rain:   0.0000
# partition residual: 1.2212e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2413
#    vol. out giuh:   0.2413
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.6189
#   vol.soil2latflow:   1.0541
#    vol. soil to gw:   0.0084
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1319
#   vol. soil resid.: 8.6042e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0541
#   vol. from nash:   1.0395
#  final vol. nash:   0.0147
# nash casc resid.: -3.0236e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0084
#      vol from gw:   0.2202
# final gw.storage:   1.2721
#     gw. residual: -5.7732e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0589
#     volume input:   0.4771
#    volume output:   1.0738
#     final volume:   1.4622
#         residual: 1.3323e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0430
#       infiltration:   0.4341
#  vol. et from rain:   0.0000
# partition residual: 6.1062e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0430
#    vol. out giuh:   0.0430
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5750
#     vol. into soil:   0.4341
#   vol.soil2latflow:   0.8093
#    vol. soil to gw:   0.0210
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1787
#   vol. soil resid.: 1.0547e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8093
#   vol. from nash:   0.7963
#  final vol. nash:   0.0130
# nash casc resid.: -1.7174e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0210
#      vol from gw:   0.2215
# final gw.storage:   1.2834
#     gw. residual: -6.6613e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0521
#     volume input:   0.3457
#    volume output:   1.0020
#     final volume:   1.3958
#         residual: -1.7764e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0608
#       infiltration:   0.2849
#  vol. et from rain:   0.0000
# partition residual: -2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0608
#    vol. out giuh:   0.0608
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5682
#     vol. into soil:   0.2849
#   vol.soil2latflow:   0.7213
#    vol. soil to gw:   0.0055
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1263
#   vol. soil resid.: -3.0531e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7213
#   vol. from nash:   0.7111
#  final vol. nash:   0.0102
# nash casc resid.: 1.8839e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0055
#      vol from gw:   0.2199
# final gw.storage:   1.2694
#     gw. residual: 2.2204e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0793
#     volume input:   0.3529
#    volume output:   1.0062
#     final volume:   1.4260
#         residual: 1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0447
#       infiltration:   0.3082
#  vol. et from rain:   0.0000
# partition residual: -2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0447
#    vol. out giuh:   0.0447
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5954
#     vol. into soil:   0.3082
#   vol.soil2latflow:   0.7413
#    vol. soil to gw:   0.0082
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1541
#   vol. soil resid.: 1.7208e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7413
#   vol. from nash:   0.7299
#  final vol. nash:   0.0113
# nash casc resid.: -7.1818e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0082
#      vol from gw:   0.2202
# final gw.storage:   1.2719
#     gw. residual: 1.1102e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0697
#     volume input:   0.4748
#    volume output:   1.0180
#     final volume:   1.5265
#         residual: -4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0180
#       infiltration:   0.4568
#  vol. et from rain:   0.0000
# partition residual: 2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0180
#    vol. out giuh:   0.0180
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5858
#     vol. into soil:   0.4568
#   vol.soil2latflow:   0.7760
#    vol. soil to gw:   0.0470
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2197
#   vol. soil resid.: 2.1927e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7760
#   vol. from nash:   0.7631
#  final vol. nash:   0.0129
# nash casc resid.: -2.0314e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0470
#      vol from gw:   0.2240
# final gw.storage:   1.3068
#     gw. residual: -2.8866e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0708
#     volume input:   0.5479
#    volume output:   1.1872
#     final volume:   1.4315
#         residual: 7.3275e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0878
#       infiltration:   0.4601
#  vol. et from rain:   0.0000
# partition residual: 1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0878
#    vol. out giuh:   0.0878
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5869
#     vol. into soil:   0.4601
#   vol.soil2latflow:   0.8788
#    vol. soil to gw:   0.0121
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1560
#   vol. soil resid.: 1.9429e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8788
#   vol. from nash:   0.8655
#  final vol. nash:   0.0133
# nash casc resid.: 5.1001e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0121
#      vol from gw:   0.2206
# final gw.storage:   1.2754
#     gw. residual: 2.4425e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0587
#     volume input:   0.3383
#    volume output:   0.9978
#     final volume:   1.3993
#         residual: 6.2172e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0089
#       infiltration:   0.3294
#  vol. et from rain:   0.0000
# partition residual: -8.8818e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0089
#    vol. out giuh:   0.0089
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5748
#     vol. into soil:   0.3294
#   vol.soil2latflow:   0.7628
#    vol. soil to gw:   0.0606
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0809
#   vol. soil resid.: 2.4980e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7628
#   vol. from nash:   0.7505
#  final vol. nash:   0.0123
# nash casc resid.: -3.0705e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0606
#      vol from gw:   0.2261
# final gw.storage:   1.3184
#     gw. residual: 5.9952e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0808
#     volume input:   0.5266
#    volume output:   0.8641
#     final volume:   1.7434
#         residual: 8.2157e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0156
#       infiltration:   0.5111
#  vol. et from rain:   0.0000
# partition residual: 9.9920e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0156
#    vol. out giuh:   0.0156
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5970
#     vol. into soil:   0.5111
#   vol.soil2latflow:   0.6225
#    vol. soil to gw:   0.0777
#  vol. et from soil:   0.0000
#    final vol. soil:   0.4079
#   vol. soil resid.: 1.1102e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.6225
#   vol. from nash:   0.6130
#  final vol. nash:   0.0094
# nash casc resid.: -9.5063e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0777
#      vol from gw:   0.2261
# final gw.storage:   1.3355
#     gw. residual: 6.2172e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.8186
#    volume output:   1.4745
#     final volume:   1.4034
#         residual: -1.9984e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2270
#       infiltration:   0.5916
#  vol. et from rain:   0.0000
# partition residual: 8.8818e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2270
#    vol. out giuh:   0.2270
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.5916
#   vol.soil2latflow:   1.0274
#    vol. soil to gw:   0.0081
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1316
#   vol. soil resid.: -3.0809e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0274
#   vol. from nash:   1.0134
#  final vol. nash:   0.0140
# nash casc resid.: 1.6966e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0081
#      vol from gw:   0.2201
# final gw.storage:   1.2718
#     gw. residual: -3.1086e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.7773
#    volume output:   1.4382
#     final volume:   1.3985
#         residual: -2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1374
#       infiltration:   0.6399
#  vol. et from rain:   0.0000
# partition residual: 1.6653e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1374
#    vol. out giuh:   0.1374
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.6399
#   vol.soil2latflow:   1.0799
#    vol. soil to gw:   0.0153
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1202
#   vol. soil resid.: -3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0799
#   vol. from nash:   1.0643
#  final vol. nash:   0.0155
# nash casc resid.: -1.4606e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0153
#      vol from gw:   0.2209
# final gw.storage:   1.2784
#     gw. residual: 6.6613e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.1004
#     volume input:   0.9950
#    volume output:   1.5341
#     final volume:   1.5613
#         residual: 3.7748e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2907
#       infiltration:   0.7042
#  vol. et from rain:   0.0000
# partition residual: -3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2907
#    vol. out giuh:   0.2907
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6166
#     vol. into soil:   0.7042
#   vol.soil2latflow:   1.0231
#    vol. soil to gw:   0.0100
#  vol. et from soil:   0.0000
#    final vol. soil:   0.2877
#   vol. soil resid.: 2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0231
#   vol. from nash:   1.0086
#  final vol. nash:   0.0145
# nash casc resid.: -6.5919e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0100
#      vol from gw:   0.2203
# final gw.storage:   1.2736
#     gw. residual: -1.9984e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3712
#    volume output:   1.0110
#     final volume:   1.4195
#         residual: -4.2188e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0499
#       infiltration:   0.3213
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0499
#    vol. out giuh:   0.0499
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5754
#     vol. into soil:   0.3213
#   vol.soil2latflow:   0.7409
#    vol. soil to gw:   0.0080
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1478
#   vol. soil resid.: -2.4980e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7409
#   vol. from nash:   0.7299
#  final vol. nash:   0.0110
# nash casc resid.: -9.9920e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0080
#      vol from gw:   0.2202
# final gw.storage:   1.2717
#     gw. residual: -8.8818e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.5479
#    volume output:   1.1904
#     final volume:   1.4169
#         residual: -1.1102e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0990
#       infiltration:   0.4490
#  vol. et from rain:   0.0000
# partition residual: 7.7716e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0990
#    vol. out giuh:   0.0990
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.4490
#   vol.soil2latflow:   0.8712
#    vol. soil to gw:   0.0088
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1445
#   vol. soil resid.: 1.3878e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8712
#   vol. from nash:   0.8588
#  final vol. nash:   0.0124
# nash casc resid.: 1.1727e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0088
#      vol from gw:   0.2202
# final gw.storage:   1.2724
#     gw. residual: 2.4425e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0571
#     volume input:   0.5076
#    volume output:   1.1351
#     final volume:   1.4296
#         residual: -2.8866e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0763
#       infiltration:   0.4313
#  vol. et from rain:   0.0000
# partition residual: 1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0763
#    vol. out giuh:   0.0763
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5732
#     vol. into soil:   0.4313
#   vol.soil2latflow:   0.8384
#    vol. soil to gw:   0.0102
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1559
#   vol. soil resid.: -1.6376e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8384
#   vol. from nash:   0.8258
#  final vol. nash:   0.0126
# nash casc resid.: 3.4243e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0102
#      vol from gw:   0.2204
# final gw.storage:   1.2737
#     gw. residual: -1.7764e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.1004
#     volume input:   0.5513
#    volume output:   0.9168
#     final volume:   1.7350
#         residual: 6.4393e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0238
#       infiltration:   0.5275
#  vol. et from rain:   0.0000
# partition residual: 1.1102e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0238
#    vol. out giuh:   0.0238
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6166
#     vol. into soil:   0.5275
#   vol.soil2latflow:   0.6689
#    vol. soil to gw:   0.0544
#  vol. et from soil:   0.0000
#    final vol. soil:   0.4208
#   vol. soil resid.: 4.4409e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.6689
#   vol. from nash:   0.6583
#  final vol. nash:   0.0106
# nash casc resid.: -2.9629e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0544
#      vol from gw:   0.2240
# final gw.storage:   1.3142
#     gw. residual: 3.9968e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0780
#     volume input:   0.8603
#    volume output:   1.5660
#     final volume:   1.3722
#         residual: -3.7748e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2960
#       infiltration:   0.5643
#  vol. et from rain:   0.0000
# partition residual: 2.3315e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2960
#    vol. out giuh:   0.2960
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5941
#     vol. into soil:   0.5643
#   vol.soil2latflow:   1.0502
#    vol. soil to gw:   0.0055
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1027
#   vol. soil resid.: -2.9143e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0502
#   vol. from nash:   1.0363
#  final vol. nash:   0.0139
# nash casc resid.: 3.8511e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0055
#      vol from gw:   0.2199
# final gw.storage:   1.2695
#     gw. residual: -6.2172e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4430
#    volume output:   1.1384
#     final volume:   1.3639
#         residual: -2.8866e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1326
#       infiltration:   0.3104
#  vol. et from rain:   0.0000
# partition residual: 1.1102e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1326
#    vol. out giuh:   0.1326
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3104
#   vol.soil2latflow:   0.7862
#    vol. soil to gw:   0.0030
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0966
#   vol. soil resid.: 9.8532e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7862
#   vol. from nash:   0.7771
#  final vol. nash:   0.0091
# nash casc resid.: -3.1572e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0030
#      vol from gw:   0.2197
# final gw.storage:   1.2672
#     gw. residual: -2.6645e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0747
#     volume input:   0.6238
#    volume output:   1.2368
#     final volume:   1.4617
#         residual: 2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0307
#       infiltration:   0.5931
#  vol. et from rain:   0.0000
# partition residual: 1.3323e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0307
#    vol. out giuh:   0.0307
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5908
#     vol. into soil:   0.5931
#   vol.soil2latflow:   0.9816
#    vol. soil to gw:   0.0519
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1504
#   vol. soil resid.: -1.2212e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.9816
#   vol. from nash:   0.9660
#  final vol. nash:   0.0156
# nash casc resid.: 1.3496e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0519
#      vol from gw:   0.2245
# final gw.storage:   1.3113
#     gw. residual: -3.3307e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.9205
#    volume output:   1.5528
#     final volume:   1.4270
#         residual: -4.2188e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2236
#       infiltration:   0.6969
#  vol. et from rain:   0.0000
# partition residual: 5.5511e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2236
#    vol. out giuh:   0.2236
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.6969
#   vol.soil2latflow:   1.1088
#    vol. soil to gw:   0.0122
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1515
#   vol. soil resid.: -3.2196e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.1088
#   vol. from nash:   1.0931
#  final vol. nash:   0.0156
# nash casc resid.: 6.2797e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0122
#      vol from gw:   0.2205
# final gw.storage:   1.2756
#     gw. residual: 2.2204e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0641
#     volume input:   0.3450
#    volume output:   0.9874
#     final volume:   1.4218
#         residual: 3.3307e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0468
#       infiltration:   0.2982
#  vol. et from rain:   0.0000
# partition residual: 6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0468
#    vol. out giuh:   0.0468
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5803
#     vol. into soil:   0.2982
#   vol.soil2latflow:   0.7204
#    vol. soil to gw:   0.0077
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1503
#   vol. soil resid.: 6.1062e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7204
#   vol. from nash:   0.7095
#  final vol. nash:   0.0109
# nash casc resid.: -5.6899e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0077
#      vol from gw:   0.2202
# final gw.storage:   1.2714
#     gw. residual: 1.9984e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4081
#    volume output:   1.0935
#     final volume:   1.3740
#         residual: 4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1005
#       infiltration:   0.3076
#  vol. et from rain:   0.0000
# partition residual: -6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1005
#    vol. out giuh:   0.1005
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5754
#     vol. into soil:   0.3076
#   vol.soil2latflow:   0.7732
#    vol. soil to gw:   0.0037
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1061
#   vol. soil resid.: -8.1879e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7732
#   vol. from nash:   0.7635
#  final vol. nash:   0.0097
# nash casc resid.: -9.9920e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0037
#      vol from gw:   0.2197
# final gw.storage:   1.2679
#     gw. residual: 8.8818e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0575
#     volume input:   0.4280
#    volume output:   1.0463
#     final volume:   1.4392
#         residual: -6.8834e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0299
#       infiltration:   0.3981
#  vol. et from rain:   0.0000
# partition residual: -3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0299
#    vol. out giuh:   0.0299
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5737
#     vol. into soil:   0.3981
#   vol.soil2latflow:   0.7948
#    vol. soil to gw:   0.0220
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1549
#   vol. soil resid.: 1.2768e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7948
#   vol. from nash:   0.7834
#  final vol. nash:   0.0113
# nash casc resid.: -2.1216e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0220
#      vol from gw:   0.2217
# final gw.storage:   1.2842
#     gw. residual: -8.2157e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3536
#    volume output:   1.0428
#     final volume:   1.3702
#         residual: 1.7764e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0852
#       infiltration:   0.2684
#  vol. et from rain:   0.0000
# partition residual: 3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0852
#    vol. out giuh:   0.0852
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.2684
#   vol.soil2latflow:   0.7379
#    vol. soil to gw:   0.0033
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1027
#   vol. soil resid.: -1.5543e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7379
#   vol. from nash:   0.7282
#  final vol. nash:   0.0097
# nash casc resid.: 1.6081e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0033
#      vol from gw:   0.2197
# final gw.storage:   1.2675
#     gw. residual: 3.5527e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.9579
#    volume output:   1.6934
#     final volume:   1.3238
#         residual: 1.9984e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.4553
#       infiltration:   0.5026
#  vol. et from rain:   0.0000
# partition residual: 6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.4553
#    vol. out giuh:   0.4553
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.5026
#   vol.soil2latflow:   1.0185
#    vol. soil to gw:   0.0030
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0565
#   vol. soil resid.: 5.5511e-17
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0185
#   vol. from nash:   1.0068
#  final vol. nash:   0.0117
# nash casc resid.: -5.8287e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0030
#      vol from gw:   0.2196
# final gw.storage:   1.2673
#     gw. residual: 5.3291e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.7196
#    volume output:   1.3983
#     final volume:   1.3806
#         residual: 5.1070e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1124
#       infiltration:   0.6071
#  vol. et from rain:   0.0000
# partition residual: -4.4409e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1124
#    vol. out giuh:   0.1124
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.6071
#   vol.soil2latflow:   1.0649
#    vol. soil to gw:   0.0159
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1018
#   vol. soil resid.: 1.6931e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.0649
#   vol. from nash:   1.0494
#  final vol. nash:   0.0155
# nash casc resid.: 3.5388e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0159
#      vol from gw:   0.2209
# final gw.storage:   1.2788
#     gw. residual: 3.5527e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0596
#     volume input:   0.3445
#    volume output:   1.0164
#     final volume:   1.3877
#         residual: -5.1070e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0309
#       infiltration:   0.3135
#  vol. et from rain:   0.0000
# partition residual: 3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0309
#    vol. out giuh:   0.0309
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5757
#     vol. into soil:   0.3135
#   vol.soil2latflow:   0.7646
#    vol. soil to gw:   0.0140
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1106
#   vol. soil resid.: 5.1348e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7646
#   vol. from nash:   0.7526
#  final vol. nash:   0.0120
# nash casc resid.: -1.5023e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0140
#      vol from gw:   0.2209
# final gw.storage:   1.2770
#     gw. residual: -3.1086e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0998
#     volume input:   1.3766
#    volume output:   1.8865
#     final volume:   1.5899
#         residual: -4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.6806
#       infiltration:   0.6959
#  vol. et from rain:   0.0000
# partition residual: 6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.6806
#    vol. out giuh:   0.6806
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6159
#     vol. into soil:   0.6959
#   vol.soil2latflow:   0.9861
#    vol. soil to gw:   0.0051
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3207
#   vol. soil resid.: -8.8818e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.9861
#   vol. from nash:   0.9741
#  final vol. nash:   0.0120
# nash casc resid.: -2.6021e-17
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0051
#      vol from gw:   0.2198
# final gw.storage:   1.2692
#     gw. residual: 5.1070e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3513
#    volume output:   0.9579
#     final volume:   1.4528
#         residual: 4.8850e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0342
#       infiltration:   0.3171
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0342
#    vol. out giuh:   0.0342
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3171
#   vol.soil2latflow:   0.7031
#    vol. soil to gw:   0.0121
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1774
#   vol. soil resid.: -3.3307e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7031
#   vol. from nash:   0.6922
#  final vol. nash:   0.0109
# nash casc resid.: 2.0782e-15
#
# ...
#    volume output:   1.0290
#     final volume:   1.4644
#         residual: 4.4409e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0269
#       infiltration:   0.4072
#  vol. et from rain:   0.0000
# partition residual: -2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0269
#    vol. out giuh:   0.0269
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.4072
#   vol.soil2latflow:   0.7801
#    vol. soil to gw:   0.0251
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1774
#   vol. soil resid.: -1.0547e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7801
#   vol. from nash:   0.7684
#  final vol. nash:   0.0117
# nash casc resid.: 2.1233e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0251
#      vol from gw:   0.2220
# final gw.storage:   1.2870
#     gw. residual: -6.6613e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0592
#     volume input:   0.3828
#    volume output:   0.9610
#     final volume:   1.4810
#         residual: 4.8850e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0056
#       infiltration:   0.3772
#  vol. et from rain:   0.0000
# partition residual: -5.5511e-17
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0056
#    vol. out giuh:   0.0056
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5753
#     vol. into soil:   0.3772
#   vol.soil2latflow:   0.7252
#    vol. soil to gw:   0.1005
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1269
#   vol. soil resid.: 6.9389e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7252
#   vol. from nash:   0.7148
#  final vol. nash:   0.0104
# nash casc resid.: 1.0061e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.1005
#      vol from gw:   0.2303
# final gw.storage:   1.3541
#     gw. residual: 2.6645e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3890
#    volume output:   1.0812
#     final volume:   1.3672
#         residual: 1.5543e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0315
#       infiltration:   0.3575
#  vol. et from rain:   0.0000
# partition residual: -1.3323e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0315
#    vol. out giuh:   0.0315
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3575
#   vol.soil2latflow:   0.8286
#    vol. soil to gw:   0.0158
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0886
#   vol. soil resid.: 2.3453e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.8286
#   vol. from nash:   0.8164
#  final vol. nash:   0.0122
# nash casc resid.: -3.2613e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0158
#      vol from gw:   0.2211
# final gw.storage:   1.2786
#     gw. residual: -6.6613e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0752
#     volume input:   1.1664
#    volume output:   1.7884
#     final volume:   1.4532
#         residual: 8.8818e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1397
#       infiltration:   1.0266
#  vol. et from rain:   0.0000
# partition residual: 6.6613e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1397
#    vol. out giuh:   0.1397
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5913
#     vol. into soil:   1.0266
#   vol.soil2latflow:   1.4248
#    vol. soil to gw:   0.0488
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1444
#   vol. soil resid.: -1.8319e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.4248
#   vol. from nash:   1.4034
#  final vol. nash:   0.0215
# nash casc resid.: 2.1268e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0488
#      vol from gw:   0.2238
# final gw.storage:   1.3088
#     gw. residual: 3.5527e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0572
#     volume input:   0.4321
#    volume output:   1.2061
#     final volume:   1.2833
#         residual: -3.1086e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.3866
#       infiltration:   0.0456
#  vol. et from rain:   0.0000
# partition residual: -2.3592e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.3866
#    vol. out giuh:   0.3866
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5733
#     vol. into soil:   0.0456
#   vol.soil2latflow:   0.6002
#    vol. soil to gw:   0.0001
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0186
#   vol. soil resid.: -9.6451e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.6002
#   vol. from nash:   0.5989
#  final vol. nash:   0.0013
# nash casc resid.: 2.4861e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0001
#      vol from gw:   0.2193
# final gw.storage:   1.2646
#     gw. residual: -6.6613e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0939
#     volume input:   0.6926
#    volume output:   1.1772
#     final volume:   1.6092
#         residual: -1.3323e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.2312
#       infiltration:   0.4614
#  vol. et from rain:   0.0000
# partition residual: 2.9421e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.2312
#    vol. out giuh:   0.2312
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6100
#     vol. into soil:   0.4614
#   vol.soil2latflow:   0.7263
#    vol. soil to gw:   0.0048
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3403
#   vol. soil resid.: 1.1102e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7263
#   vol. from nash:   0.7162
#  final vol. nash:   0.0100
# nash casc resid.: -3.1572e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0048
#      vol from gw:   0.2198
# final gw.storage:   1.2689
#     gw. residual: -3.9968e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.1004
#     volume input:   0.8603
#    volume output:   1.3454
#     final volume:   1.6154
#         residual: 1.9984e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1824
#       infiltration:   0.6778
#  vol. et from rain:   0.0000
# partition residual: 1.8874e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1824
#    vol. out giuh:   0.1824
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6166
#     vol. into soil:   0.6778
#   vol.soil2latflow:   0.9423
#    vol. soil to gw:   0.0144
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3377
#   vol. soil resid.: 2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.9423
#   vol. from nash:   0.9286
#  final vol. nash:   0.0137
# nash casc resid.: -1.6376e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0144
#      vol from gw:   0.2206
# final gw.storage:   1.2777
#     gw. residual: -1.3323e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0612
#     volume input:   0.9067
#    volume output:   1.4850
#     final volume:   1.4829
#         residual: 1.3323e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0366
#       infiltration:   0.8700
#  vol. et from rain:   0.0000
# partition residual: 2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0366
#    vol. out giuh:   0.0366
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5774
#     vol. into soil:   0.8700
#   vol.soil2latflow:   1.2181
#    vol. soil to gw:   0.1153
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1140
#   vol. soil resid.: 1.5127e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.2181
#   vol. from nash:   1.1994
#  final vol. nash:   0.0186
# nash casc resid.: -3.5562e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.1153
#      vol from gw:   0.2303
# final gw.storage:   1.3689
#     gw. residual: -1.7764e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3786
#    volume output:   1.0183
#     final volume:   1.4196
#         residual: -6.2172e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0518
#       infiltration:   0.3268
#  vol. et from rain:   0.0000
# partition residual: 2.2204e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0518
#    vol. out giuh:   0.0518
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3268
#   vol.soil2latflow:   0.7463
#    vol. soil to gw:   0.0081
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1478
#   vol. soil resid.: -1.8319e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7463
#   vol. from nash:   0.7356
#  final vol. nash:   0.0107
# nash casc resid.: 3.6082e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0081
#      vol from gw:   0.2202
# final gw.storage:   1.2718
#     gw. residual: -4.2188e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3553
#    volume output:   1.0103
#     final volume:   1.4043
#         residual: 4.2188e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0567
#       infiltration:   0.2986
#  vol. et from rain:   0.0000
# partition residual: 3.3307e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0567
#    vol. out giuh:   0.0567
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.2986
#   vol.soil2latflow:   0.7336
#    vol. soil to gw:   0.0062
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1343
#   vol. soil resid.: -2.2204e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7336
#   vol. from nash:   0.7227
#  final vol. nash:   0.0109
# nash casc resid.: 5.1001e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0062
#      vol from gw:   0.2200
# final gw.storage:   1.2701
#     gw. residual: 3.9968e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4175
#    volume output:   1.0454
#     final volume:   1.4315
#         residual: -4.4409e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0553
#       infiltration:   0.3623
#  vol. et from rain:   0.0000
# partition residual: -1.6653e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0553
#    vol. out giuh:   0.0553
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3623
#   vol.soil2latflow:   0.7697
#    vol. soil to gw:   0.0098
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1582
#   vol. soil resid.: -4.1633e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7697
#   vol. from nash:   0.7585
#  final vol. nash:   0.0112
# nash casc resid.: 1.0755e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0098
#      vol from gw:   0.2204
# final gw.storage:   1.2733
#     gw. residual: -1.7764e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.4239
#    volume output:   1.0787
#     final volume:   1.4045
#         residual: 5.5511e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0762
#       infiltration:   0.3477
#  vol. et from rain:   0.0000
# partition residual: 1.6653e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0762
#    vol. out giuh:   0.0762
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5755
#     vol. into soil:   0.3477
#   vol.soil2latflow:   0.7825
#    vol. soil to gw:   0.0064
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1343
#   vol. soil resid.: -2.0262e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7825
#   vol. from nash:   0.7719
#  final vol. nash:   0.0106
# nash casc resid.: 3.5544e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0064
#      vol from gw:   0.2200
# final gw.storage:   1.2703
#     gw. residual: 3.7748e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0367
#     volume input:   0.3470
#    volume output:   1.0115
#     final volume:   1.3722
#         residual: -9.3259e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1047
#       infiltration:   0.2423
#  vol. et from rain:   0.0000
# partition residual: -1.9429e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1047
#    vol. out giuh:   0.1047
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5684
#     vol. into soil:   0.2423
#   vol.soil2latflow:   0.6874
#    vol. soil to gw:   0.0023
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1209
#   vol. soil resid.: -5.6899e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.6874
#   vol. from nash:   0.6792
#  final vol. nash:   0.0082
# nash casc resid.: 3.7297e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4683
#        vol to gw:   0.0023
#      vol from gw:   0.2194
# final gw.storage:   1.2513
#     gw. residual: -6.4393e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.1003
#     volume input:   1.1509
#    volume output:   1.6031
#     final volume:   1.6481
#         residual: -6.4393e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1864
#       infiltration:   0.9645
#  vol. et from rain:   0.0000
# partition residual: -3.8858e-15
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1864
#    vol. out giuh:   0.1864
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.6164
#     vol. into soil:   0.9645
#   vol.soil2latflow:   1.1942
#    vol. soil to gw:   0.0374
#  vol. et from soil:   0.0000
#    final vol. soil:   0.3494
#   vol. soil resid.: -8.3267e-16
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   1.1942
#   vol. from nash:   1.1772
#  final vol. nash:   0.0169
# nash casc resid.: 1.1449e-15
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0374
#      vol from gw:   0.2225
# final gw.storage:   1.2987
#     gw. residual: 3.7748e-15
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0593
#     volume input:   0.3683
#    volume output:   1.0789
#     final volume:   1.3487
#         residual: 2.2204e-16
#
# PARTITION MASS BALANCE
#     surface runoff:   0.1543
#       infiltration:   0.2140
#  vol. et from rain:   0.0000
# partition residual: 4.1633e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.1543
#    vol. out giuh:   0.1543
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5754
#     vol. into soil:   0.2140
#   vol.soil2latflow:   0.7051
#    vol. soil to gw:   0.0012
#  vol. et from soil:   0.0000
#    final vol. soil:   0.0831
#   vol. soil resid.: -4.1633e-17
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7051
#   vol. from nash:   0.6979
#  final vol. nash:   0.0072
# nash casc resid.: 7.2945e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0012
#      vol from gw:   0.2195
# final gw.storage:   1.2656
#     gw. residual: -2.2204e-16
#
# GLOBAL MASS BALANCE
#   initial volume:   2.0646
#     volume input:   0.3444
#    volume output:   1.0080
#     final volume:   1.4010
#         residual: 4.8850e-15
#
# PARTITION MASS BALANCE
#     surface runoff:   0.0582
#       infiltration:   0.2861
#  vol. et from rain:   0.0000
# partition residual: -8.8818e-16
#
# GIUH MASS BALANCE
#   vol. into giuh:   0.0582
#    vol. out giuh:   0.0582
#  vol. end giuh q:   0.0000
#    giuh residual: 0.0000e+00
#
# SOIL WATER MASS BALANCE
#      init soil vol:   0.5807
#     vol. into soil:   0.2861
#   vol.soil2latflow:   0.7298
#    vol. soil to gw:   0.0057
#  vol. et from soil:   0.0000
#    final vol. soil:   0.1313
#   vol. soil resid.: 2.2204e-15
#
# NASH CASCADE CONCEPTUAL RESERVOIR MASS BALANCE
#     vol. to nash:   0.7298
#   vol. from nash:   0.7193
#  final vol. nash:   0.0105
# nash casc resid.: -9.4369e-16
#
# GROUNDWATER CONCEPTUAL RESERVOIR MASS BALANCE
# init gw. storage:   1.4839
#        vol to gw:   0.0057
#      vol from gw:   0.2200
# final gw.storage:   1.2697
#     gw. residual: 2.6645e-15

# %%
# file = pd.read_csv('./trial_calib/output_calib/cat-3400554_output.csv')
file = pd.read_csv('./Carmel_inputs_January_2017/output_decjanfeb/cat-3400624_output.csv')
discharge = file['land_surface_water__runoff_volume_flux']
giuh = file['GIUH_RUNOFF']
lateral = file['NASH_LATERAL_RUNOFF']
gw = file['DEEP_GW_TO_CHANNEL_FLUX']

# %%
file = pd.read_csv('./trial_calib/output_calib/cat-34005541_output.csv')
discharge1 = file['land_surface_water__runoff_depth']
giuh1 = file['GIUH_RUNOFF']
lateral1 = file['NASH_LATERAL_RUNOFF']
gw1 = file['DEEP_GW_TO_CHANNEL_FLUX']

# %%
pip install dataretrieval
# Out:
# Requirement already satisfied: dataretrieval in /opt/conda/lib/python3.9/site-packages (1.0.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from dataretrieval) (2.31.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from dataretrieval) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from pandas->dataretrieval) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->dataretrieval) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->dataretrieval) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dataretrieval.nwis as nwis
import pandas as pd

discharge_nwis = nwis.get_record(sites="11143200", parameterCd='00060', start="2016-12-01", end="2017-02-28")
discharge_resampled = discharge_nwis.select_dtypes(include=['float64', 'int64']).resample('H').mean() # Hourly averaged value
discharge_dataframe = discharge_resampled

# %%
discharge_usgs1 = discharge_resampled['00060'].values
discharge_usgs = discharge_usgs1/35.315

# %%
# plt.plot(discharge_usgs)
plt.plot(discharge)
# plt.plot(discharge1)

# %%
np.sum(discharge)
# Out:
# 293.34574452879286

# %%
# plt.plot(giuh1, color = 'r')
plt.plot(giuh, color = 'g')

# %%
plt.plot(lateral)
plt.plot(lateral1)

# %%
plt.plot(gw)
plt.plot(gw1)
